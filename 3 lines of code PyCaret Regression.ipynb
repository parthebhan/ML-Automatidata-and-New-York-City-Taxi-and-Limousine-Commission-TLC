# %% [markdown]
# #  3 lines of code PyCaret Regression - Best Model selection for the Automatidata_Preprocessed dataset
#
#     Gradient Boosting Regressor
#     Light Gradient Boosting Machine
#     Ridge Regression
#     Least Angle Regression
#     Bayesian Ridge
#     Linear Regression
#     Lasso Regression
#     Lasso Least Angle Regression
#     Huber Regressor
#     Extreme Gradient Boosting
#     Elastic Net
#     K Neighbors Regressor
#     Random Forest Regressor
#     Extra Trees Regressor
#     Decision Tree Regressor
#     Passive Aggressive Regressor
#     Orthogonal Matching Pursuit
#     AdaBoost Regressor
#     Dummy Regressor

# %%
import pandas as pd
import numpy as np

# %%
# lets us see all of the columns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('df2.csv')
df.head()
# Out:
#    VendorID  passenger_count  fare_amount  mean_distance  mean_duration  \
# 0         2                6         13.0       3.521667      22.847222
# 1         1                1         16.0       3.108889      24.470370
# 2         1                1          6.5       0.881429       7.250000
# 3         2                1         20.5       3.700000      30.250000
# 4         2                1         16.5       4.435000      14.616667
#
#    rush_hour
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
from pycaret.regression import *
s = setup(df, target = 'fare_amount')
best = compare_models()
# Out:
# <style type="text/css">
# #T_a99df_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a99df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a99df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a99df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a99df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a99df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a99df_row0_col1" class="data row0 col1" >3666</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a99df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a99df_row1_col1" class="data row1 col1" >fare_amount</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a99df_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a99df_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a99df_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a99df_row3_col1" class="data row3 col1" >(22699, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a99df_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a99df_row4_col1" class="data row4 col1" >(22699, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a99df_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a99df_row5_col1" class="data row5 col1" >(15889, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a99df_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a99df_row6_col1" class="data row6 col1" >(6810, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a99df_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a99df_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a99df_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a99df_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a99df_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a99df_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a99df_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a99df_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a99df_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a99df_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a99df_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a99df_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a99df_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a99df_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a99df_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a99df_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a99df_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a99df_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a99df_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a99df_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a99df_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a99df_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a99df_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a99df_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a99df_row18_col1" class="data row18 col1" >3197</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_10445 th {
#   text-align: left;
# }
# #T_10445_row0_col0, #T_10445_row0_col1, #T_10445_row0_col5, #T_10445_row0_col6, #T_10445_row1_col0, #T_10445_row1_col1, #T_10445_row1_col2, #T_10445_row1_col3, #T_10445_row1_col4, #T_10445_row1_col5, #T_10445_row1_col6, #T_10445_row2_col0, #T_10445_row2_col1, #T_10445_row2_col2, #T_10445_row2_col3, #T_10445_row2_col4, #T_10445_row2_col5, #T_10445_row2_col6, #T_10445_row3_col0, #T_10445_row3_col1, #T_10445_row3_col2, #T_10445_row3_col3, #T_10445_row3_col4, #T_10445_row3_col5, #T_10445_row3_col6, #T_10445_row4_col0, #T_10445_row4_col1, #T_10445_row4_col2, #T_10445_row4_col3, #T_10445_row4_col4, #T_10445_row4_col5, #T_10445_row4_col6, #T_10445_row5_col0, #T_10445_row5_col1, #T_10445_row5_col2, #T_10445_row5_col3, #T_10445_row5_col4, #T_10445_row5_col5, #T_10445_row5_col6, #T_10445_row6_col0, #T_10445_row6_col1, #T_10445_row6_col2, #T_10445_row6_col3, #T_10445_row6_col4, #T_10445_row6_col5, #T_10445_row6_col6, #T_10445_row7_col0, #T_10445_row7_col1, #T_10445_row7_col2, #T_10445_row7_col3, #T_10445_row7_col4, #T_10445_row7_col5, #T_10445_row7_col6, #T_10445_row8_col0, #T_10445_row8_col1, #T_10445_row8_col2, #T_10445_row8_col3, #T_10445_row8_col4, #T_10445_row8_col5, #T_10445_row8_col6, #T_10445_row9_col0, #T_10445_row9_col2, #T_10445_row9_col3, #T_10445_row9_col4, #T_10445_row10_col0, #T_10445_row10_col1, #T_10445_row10_col2, #T_10445_row10_col3, #T_10445_row10_col4, #T_10445_row10_col5, #T_10445_row10_col6, #T_10445_row11_col0, #T_10445_row11_col1, #T_10445_row11_col2, #T_10445_row11_col3, #T_10445_row11_col4, #T_10445_row11_col5, #T_10445_row11_col6, #T_10445_row12_col0, #T_10445_row12_col1, #T_10445_row12_col2, #T_10445_row12_col3, #T_10445_row12_col4, #T_10445_row12_col5, #T_10445_row12_col6, #T_10445_row13_col0, #T_10445_row13_col1, #T_10445_row13_col2, #T_10445_row13_col3, #T_10445_row13_col4, #T_10445_row13_col5, #T_10445_row13_col6, #T_10445_row14_col0, #T_10445_row14_col1, #T_10445_row14_col2, #T_10445_row14_col3, #T_10445_row14_col4, #T_10445_row14_col5, #T_10445_row14_col6, #T_10445_row15_col0, #T_10445_row15_col1, #T_10445_row15_col2, #T_10445_row15_col3, #T_10445_row15_col4, #T_10445_row15_col5, #T_10445_row15_col6, #T_10445_row16_col0, #T_10445_row16_col1, #T_10445_row16_col2, #T_10445_row16_col3, #T_10445_row16_col4, #T_10445_row16_col5, #T_10445_row16_col6, #T_10445_row17_col0, #T_10445_row17_col1, #T_10445_row17_col2, #T_10445_row17_col3, #T_10445_row17_col4, #T_10445_row17_col5, #T_10445_row17_col6, #T_10445_row18_col0, #T_10445_row18_col1, #T_10445_row18_col2, #T_10445_row18_col3, #T_10445_row18_col4, #T_10445_row18_col5, #T_10445_row18_col6 {
#   text-align: left;
# }
# #T_10445_row0_col2, #T_10445_row0_col3, #T_10445_row0_col4, #T_10445_row9_col1, #T_10445_row9_col5, #T_10445_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_10445_row0_col7, #T_10445_row1_col7, #T_10445_row2_col7, #T_10445_row3_col7, #T_10445_row4_col7, #T_10445_row5_col7, #T_10445_row6_col7, #T_10445_row7_col7, #T_10445_row8_col7, #T_10445_row9_col7, #T_10445_row10_col7, #T_10445_row11_col7, #T_10445_row12_col7, #T_10445_row13_col7, #T_10445_row14_col7, #T_10445_row15_col7, #T_10445_row16_col7, #T_10445_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_10445_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_10445">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10445_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_10445_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_10445_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_10445_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_10445_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_10445_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_10445_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_10445_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10445_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_10445_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_10445_row0_col1" class="data row0 col1" >2.1001</td>
#       <td id="T_10445_row0_col2" class="data row0 col2" >15.2523</td>
#       <td id="T_10445_row0_col3" class="data row0 col3" >3.8891</td>
#       <td id="T_10445_row0_col4" class="data row0 col4" >0.8639</td>
#       <td id="T_10445_row0_col5" class="data row0 col5" >0.2595</td>
#       <td id="T_10445_row0_col6" class="data row0 col6" >0.2457</td>
#       <td id="T_10445_row0_col7" class="data row0 col7" >0.6400</td>
#     </tr>
#     <tr>
#       <th id="T_10445_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_10445_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_10445_row1_col1" class="data row1 col1" >2.1521</td>
#       <td id="T_10445_row1_col2" class="data row1 col2" >15.4801</td>
#       <td id="T_10445_row1_col3" class="data row1 col3" >3.9226</td>
#       <td id="T_10445_row1_col4" class="data row1 col4" >0.8616</td>
#       <td id="T_10445_row1_col5" class="data row1 col5" >0.2670</td>
#       <td id="T_10445_row1_col6" class="data row1 col6" >0.2545</td>
#       <td id="T_10445_row1_col7" class="data row1 col7" >0.2590</td>
#     </tr>
#     <tr>
#       <th id="T_10445_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_10445_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_10445_row2_col1" class="data row2 col1" >2.1931</td>
#       <td id="T_10445_row2_col2" class="data row2 col2" >16.3830</td>
#       <td id="T_10445_row2_col3" class="data row2 col3" >4.0379</td>
#       <td id="T_10445_row2_col4" class="data row2 col4" >0.8533</td>
#       <td id="T_10445_row2_col5" class="data row2 col5" >0.2713</td>
#       <td id="T_10445_row2_col6" class="data row2 col6" >0.2571</td>
#       <td id="T_10445_row2_col7" class="data row2 col7" >1.0290</td>
#     </tr>
#     <tr>
#       <th id="T_10445_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_10445_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_10445_row3_col1" class="data row3 col1" >2.1484</td>
#       <td id="T_10445_row3_col2" class="data row3 col2" >16.7305</td>
#       <td id="T_10445_row3_col3" class="data row3 col3" >4.0711</td>
#       <td id="T_10445_row3_col4" class="data row3 col4" >0.8507</td>
#       <td id="T_10445_row3_col5" class="data row3 col5" >0.2627</td>
#       <td id="T_10445_row3_col6" class="data row3 col6" >0.2437</td>
#       <td id="T_10445_row3_col7" class="data row3 col7" >0.1980</td>
#     </tr>
#     <tr>
#       <th id="T_10445_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_10445_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_10445_row4_col1" class="data row4 col1" >2.1484</td>
#       <td id="T_10445_row4_col2" class="data row4 col2" >16.7305</td>
#       <td id="T_10445_row4_col3" class="data row4 col3" >4.0711</td>
#       <td id="T_10445_row4_col4" class="data row4 col4" >0.8507</td>
#       <td id="T_10445_row4_col5" class="data row4 col5" >0.2627</td>
#       <td id="T_10445_row4_col6" class="data row4 col6" >0.2437</td>
#       <td id="T_10445_row4_col7" class="data row4 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_10445_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_10445_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_10445_row5_col1" class="data row5 col1" >2.1483</td>
#       <td id="T_10445_row5_col2" class="data row5 col2" >16.7304</td>
#       <td id="T_10445_row5_col3" class="data row5 col3" >4.0711</td>
#       <td id="T_10445_row5_col4" class="data row5 col4" >0.8507</td>
#       <td id="T_10445_row5_col5" class="data row5 col5" >0.2627</td>
#       <td id=
